# %% [markdown]
# # TO DO
#
# ## Parameter
#
# - Welche Parameter werden genau gebraucht?
# - Parameter in dictionary einpflegen __(Stand 08.06. nur Dummy-Werte!)__
# - Temperatur Warmwasserspeicher auf min. 55 °C halten (Verbraucherzentrale, S. 13: https://www.verbraucherzentrale.nrw/sites/default/files/2019-04/201904_Warmwasser_Energie_Wasser-sparen_Brosch%C3%BCre_VZ-NRW.pdf
#
# ## Profile
#
# - Heizlastprofil & Wärmepumpe fehlen!
#     - lthermisches Lastprofil heat_load funktioniert noch nicht --> Datensätze vereinheitlichen
# - PV-Profil von Alion (renewable ninjas): über ein Jahr, Standort Wesseling
#
# __Achtung! Bisher hier auch nur Dummy-Profile eingepflegt!!__
# - Generisches Lastprofil Load Profile Generator: 2 Personen, arbeitend, 1h-Auflösung über ein Jahr
#
# ## Stand 16.06.22 08:49h
#
# - Multlinks im main_network geändert
# - mit halbwegs annehmbaren Daten versucht aufzufüllen
#
# __Nächste Aufgaben:__
# - thermisches Lastprofil einpflegen
# - welche Daten fehlen für einen ersten Optimierungsversuch? Lösung war: _extendable -Parameter implementieren
#     - Eine Übersicht zu erstellen (nach Tabelle in Powerpoint?) wäre wahrscheinlich sinnvoll
# - feste Grenzen für Wasserstoffspeicherung aufgrund des Picea-Systems eintragen oder Speicher, FC, Elektrolyse getrennt voneinander dimensionieren lassen?
#     - entscheiden
# - es fehlt eine Netzeinspeisung - zumindest für originales System sinnvoll
#     - mit allen abstimmen

# %%
import pypsa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import seaborn as sns
# Out:
# C:\Users\Marvin\anaconda3\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# C:\Users\Marvin\anaconda3\lib\site-packages\pypsa\networkclustering.py:16: UserWarning:
#
# The namespace `pypsa.networkclustering` is deprecated and will be removed in PyPSA v0.24. Please use `pypsa.clustering.spatial instead`.

# %% [markdown]
# # Das originale Energiesystem:
# ## PV + Batterie, Wärmepumpe + Speicher, Netzbezug

# %%
# reference network image
display.Image('./img/network_original.PNG')

# %%
# load in energy profiles

electrical_load = pd.read_csv('household_2_1h.Electricity.csv', sep = ';', decimal = ',')['Sum [kWh]'] # 1h resolution, 2-Personen Load Profile Generator
heat_load = pd.read_csv('heat_load.csv', sep = ';', decimal = ',') 
#hot_water_consum.plot()
#Annahme: 40L Warmwasser mit 45°C pro Person pro Tag und JAZ 3.0 - circa 406 kWh/a für 2 Personen (energie-experten.org) // 2.2 kWh pro 40 L

#heat_load = hot_water_consum * (2.2/40) #kWh
#heat_load[4000:4100].plot()
#plt.xlabel('Zeit')
#plt.ylabel('Heizleistung für Warmwasser [kWh]')

#print(heat_load.sum())

pv_p = pd.read_csv('Wesseling_PV_50.8203_6.9721.csv', skiprows = 3)['electricity']   # 1 year in Wesseling for 10 kWp

#pv_p.plot()

# %%
heat_load_new = heat_load#.transpose()
heat_load_new = heat_load_new.drop('Date', axis=1)
heat_load_new = heat_load_new.stack().reset_index().rename(columns={0:'value'})
#heat_load_new.rename(index = {'Date': 'Uhrzeit'})
heat_load_new
# Out:
#       level_0 level_1  value
# 0           0   01:00   2.88
# 1           0   02:00   2.94
# 2           0   03:00   2.78
# 3           0   04:00  81.34
# 4           0   05:00  81.35
# ...       ...     ...    ...
# 8755      364   20:00   3.39
# 8756      364   21:00   3.45
# 8757      364   22:00   2.18
# 8758      364   23:00   2.11
# 8759      364   00:00   2.16
#
# [8760 rows x 3 columns]

# %%
# heat_load = heat_load.set_index('Date')

# %%
#sns.heatmap(heat_load)

# %%
#Parameters:

electricity_rate = 0.5 # €/kWh
pv_infeed = 0.082 # €/kWh

lifespan_pv = 20 #years
specific_heat_power = 0.06 # kW/m² Annahme
living_space = 157 #m²
p_heat_pump = specific_heat_power * living_space

# define design parameters in dictionarys for pv, grid, electrolysis, fuellcell, heatpump, storages 
pv_params = {
    'p_nom_pv': 10,    # kWp
    'p_max_pu_pv': pv_infeed,
    'capital_cost_pv': 14000/10,
    'marginal_cost_pv': 0.02 * lifespan_pv
}

fuellcell_params = {
    'p_nom_fuelcell': 1.5, #kW_el Brennstoffzellenleistung picea
    'electrical_efficiency_fuelcell': 0.8,
    'thermal_efficiency_fuelcell': 0.2,
   # 'capital_cost_fuelcell': 1000,
   # 'marginal_cost_fuelcell': 40
}

electrolysis_params = {
    'p_nom_electrolysis': 2.3, #kW_el Wasserstofferzeugungsleistung picea
    'efficiency_electrolysis': 0.8,
 #   'capital_cost_electrolysis': 12000,
  #  'marginal_cost_electrolysis': 100
}

heatpump_params = {
    'p_nom_heatpump': p_heat_pump,
    'efficiency_heatpump': 3,
    #'p_max_pu_heatpump': *hier Kennlinie hinterlegen*
    'capital_cost_heatpump': 1000,
    'marginal_cost_heatpump': 40
}

battery_params = { # battery integrated in picea system
    'e_nom_battery': 20, #kWh picea system
    #'e_min_pu_battery': 0.2,
    #'e_max_pu_battery': 1.0,
    'capital_cost_battery': 5000,
    'marginal_cost_battery': 30,
    'standing_loss_battery': 0.01
}

heatstore_params = {
    'e_nom_heat_storage': 300, #kWh
    'e_min_pu_heat_storage': 0.6,
    'e_max_pu_heat_storage': 1.0,
    'volume': 300, #Litre
    'capital_cost_heat_storage': 750,
    'marginal_cost_heat_storage': 600,
    'standing_loss_heat_storage': 0.05
}
    
hydrogenstore_params = {
    'e_nom_heat_hydrogen': 300, #kWh_el - picea, auf 1500 kWh_el erweiterbar
 #   'e_min_pu_hydrogen': 0.6,
  #  'e_max_pu_hydrogen': 1.0,
    'capital_cost_hydrogen': 120000, #€ picea system
    'marginal_cost_hydrogen': 499.8,
    'standing_loss_hydrogen': 0.001
}


# Kommentar

# %%
# define reference network
# carrier: 'AC / DC' for electrical or 'heat / gas' for energy carrier (Bus, Link, Generator, Load)

ref_network = pypsa.Network()
ref_network.set_snapshots(range(8760))

# pv - electrical subnetwork

ref_network.add('Bus', name = 'electricity_bus')
ref_network.add('Bus', name='battery_bus')

ref_network.add('Load', name='electrical_load', bus='electricity_bus', p_set = electrical_load)    # electrical load for house

ref_network.add('Generator', name='PV', bus='electricity_bus',
                p_nom = pv_params['p_nom_pv'], p_max_pu = pv_params['p_max_pu_pv'], p_nom_extendable = True,
                capital_cost = pv_params['capital_cost_pv'], marginal_cost = pv_params['marginal_cost_pv'])
ref_network.add('Generator', name='grid', bus='electricity_bus', marginal_cost = electricity_rate)

ref_network.add('Store', name='battery', bus="battery_bus", e_nom = battery_params['e_nom_battery'],
                e_nom_extendable = True, e_cyclic=True,
                capital_cost = battery_params['capital_cost_battery'], 
                marginal_cost = battery_params['marginal_cost_battery'])   # electrical storage

ref_network.add('Link', name='house_battery_charge', bus0='electricity_bus', bus1='battery_bus', efficiency = 0.98)
ref_network.add('Link', name='house_battery_discharge', bus0='battery_bus', bus1='electricity_bus', efficiency = 0.98)


# heat subnetwork

ref_network.add('Bus', name='heat_bus')
ref_network.add('Bus', name='heat_storage_bus')

ref_network.add('Load', name='heat_load', bus='heat_bus', p_set = heat_load_new["value"])     # heat load for house

ref_network.add('Store', name='heat_storage', bus='heat_storage_bus', e_nom = heatstore_params['e_nom_heat_storage'],
                e_cyclic=True, capital_cost = heatstore_params['capital_cost_heat_storage'],
               marginal_cost = heatstore_params['marginal_cost_heat_storage'],
                standing_loss = heatstore_params['standing_loss_heat_storage'])    # warm water storage

ref_network.add('Link', name='heat_pump', bus0='electricity_bus', bus1='heat_bus', p_nom = 12.6, p_nom_extendable = True,
                capital_cost = heatpump_params['capital_cost_heatpump'], marginal_cost = electricity_rate)    # heat pump
ref_network.add('Link', name='heat_storage_charge', bus0='heat_bus', bus1='heat_storage_bus')    # charge heat storage
ref_network.add('Link', name='heat_storage_discharge', bus0='heat_storage_bus', bus1='heat_bus') # discharge heat storage

# %%
ref_network.optimize(solver_name = 'gurobi')
# Out:
# INFO:linopy.model: Solve linear problem using Gurobi solver
# ...
# Writing continuous variables.: 100%|██████████| 8/8 [00:00<00:00, 38.21it/s]
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-06-18
# Read LP format model from file C:\Users\Marvin\AppData\Local\Temp\linopy-problem-u2n16i10.lp
# Reading time = 0.35 seconds
# obj: 210243 rows, 96364 columns, 359163 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 210243 rows, 96364 columns and 359163 nonzeros
# Model fingerprint: 0x9a7a1af5
# Coefficient statistics:
#   Matrix range     [8e-02, 1e+00]
#   Objective range  [4e-01, 5e+03]
#   Bounds range     [1e+05, 1e+05]
#   RHS range        [2e-02, 3e+02]
# Presolve removed 210243 rows and 96364 columns
# Presolve time: 0.07s
# ...

# %%
print(ref_network.generators.p_nom_opt)
print(ref_network.stores.e_nom_opt)
# Out:
# Generator
# PV      1021.381106
# grid       0.000000
# Name: p_nom_opt, dtype: float64
# Store
# battery           0.0
# heat_storage    300.0
# Name: e_nom_opt, dtype: float64

# %% [markdown]
# # Erweitertes System mit einer saisonalen Wasserstoffspeicherung
#
# - überschüssiger PV-Strom wird in Batterie eingespeist
# - sobald Batterie voll geladen wird mit einem Elektrolyseur Wasserstoff erzeugt
#
# Punkte:
# - Frage: Ab wann lohnt sich eine saisonale Wasserstoffspeicherung?
#     - Strompreis
#     - H2-Komponenten marktreifer für den Heimgebrauch - billiger
#     - an welchen Stellschrauben kann noch gedreht werden?
# - Autarkiegrad erhöhen:  Netzbezug so klein wie möglich
# - welche Komponenten sind fest dimensioniert, welche können optimiert werden
#
# Feste Parameter
# - Nennleistung PV-Anlage
# - max. Kapazität Warmwasserspeicher
# - Lastprofile
# (- Batterie)
#
# Optimierende Parameter
# - Kapazität H2-Speicher
# - Nennleistung Elektrolyseur
# - Nennleistung Brennstoffzelle

# %%
# main network image
display.Image('./img/network_original_with_h2.PNG')

# %% [markdown]
# # Picea System
#
# - Wärmerückgewinnungsgrad bis zu 87%
# - verfügbare Abwärme 3.000 kWh (von Verbraucherverhalten abhängig: zwischen 2.000 und 4.000 kWh)
# - Nennleistung 7.2 kW
#
# Datenblatt:
# https://www.homepowersolutions.de/wp-content/uploads/2022/11/20221109_Marketing_picea-Datenblatt_V.3.pdf
#
# Präsentation:
# https://www.homepowersolutions.de/wp-content/uploads/2023/04/HPS-Erstinformation.pdf
#
# Brochüre:
# https://www.homepowersolutions.de/wp-content/uploads/2023/04/20230421_picea_Broschuere_Doppelseiten_V12_digital.pdf
#
# Website:
# https://www.homepowersolutions.de/produkt/

# %%
override_component_attrs = pypsa.descriptors.Dict(
    {k: v.copy() for k, v in pypsa.components.component_attrs.items()}
)
override_component_attrs["Link"].loc["bus2"] = [
    "string",
    np.nan,
    np.nan,
    "2nd bus",
    "Input (optional)",
]
override_component_attrs["Link"].loc["efficiency2"] = [
    "static or series",
    "per unit",
    1.0,
    "2nd bus efficiency",
    "Input (optional)",
]
override_component_attrs["Link"].loc["p2"] = [
    "series",
    "MW",
    0.0,
    "2nd bus output",
    "Output",
]

# %%
# define main network
# carrier: 'AC / DC' for electrical or 'heat / gas' for energy carrier (Bus, Link, Generator, Load)

main_network = pypsa.Network(override_component_attrs=override_component_attrs)
main_network.set_snapshots(range(8760))

# pv - electrical subnetwork

main_network.add('Bus', name = 'electricity_bus')
main_network.add('Bus', name='battery_bus')

main_network.add('Load', name='electrical_load', bus='electricity_bus',   # electrical load for house
                 p_set = electrical_load)

main_network.add('Generator', name='PV', bus='electricity_bus', p_nom = pv_params['p_nom_pv'],
                 p_max_pu = pv_params['p_max_pu_pv'], p_nom_extendable = True,
                capital_cost = pv_params['capital_cost_pv'], marginal_cost = pv_params['marginal_cost_pv'])
main_network.add('Generator', name='grid', bus='electricity_bus')

main_network.add('Store', name='battery', bus="battery_bus",    # electrical storage
                 e_nom = battery_params.get('e_nom_battery'))  

main_network.add('Link', name='house_battery_charge', bus0='electricity_bus', bus1='battery_bus', efficiency = 0.98)
main_network.add('Link', name='house_battery_discharge', bus0='battery_bus', bus1='electricity_bus', efficiency = 0.98)


# heat subnetwork

main_network.add('Bus', name='heat_bus')
main_network.add('Bus', name='heat_storage_bus')

main_network.add('Load', name='heat_load', bus='heat_bus', p_set = heat_load)     # heat load for house

main_network.add('Store', name='heat_storage', bus='heat_storage_bus',
                 standing_loss = 0.05)    # warm water storage

main_network.add('Link', name='heat_pump', bus0='electricity_bus', bus1='heat_bus')    # heat pump
#main_network.add('Link', name='heat_storage_charge', bus0='heat_bus', bus1='heat_storage_bus')    # charge heat storage
#main_network.add('Link', name='heat_storage_discharge', bus0='heat_storage_bus', bus1='heat_bus') # discharge heat storage

# hydrogen storage unit

main_network.add('Bus', name='hydrogen_bus', carrier='hydrogen')

main_network.add('Store', name='hydrogen_storage', bus="hydrogen_bus", e_cyclic=True)

main_network.add('Link', name='electrolysis', bus0='electricity_bus', bus1='hydrogen_bus', bus2 = 'heat_bus')

main_network.add('Link', name = 'fuelcell', bus0='hydrogen_bus',bus1='electricity_bus', bus2 = 'heat_bus')  # Multlilink fuel cell
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 32
#      29 main_network.add('Bus', name='heat_bus')
#      30 main_network.add('Bus', name='heat_storage_bus')
# ---> 32 main_network.add('Load', name='heat_load', bus='heat_bus', p_set = heat_load)     # heat load for house
#      34 main_network.add('Store', name='heat_storage', bus='heat_storage_bus',
#      35                  standing_loss = 0.05)    # warm water storage
#      37 main_network.add('Link', name='heat_pump', bus0='electricity_bus', bus1='heat_bus')    # heat pump
#
# File ~\anaconda3\lib\site-packages\pypsa\components.py:881, in Network.add(self, class_name, name, **kwargs)
#     879         new_df.at[name, k] = typ(v)
#     880     else:
# --> 881         cls_pnl[k][name] = pd.Series(data=v, index=self.snapshots, dtype=typ)
#     883 for attr in ["bus", "bus0", "bus1"]:
# ...
