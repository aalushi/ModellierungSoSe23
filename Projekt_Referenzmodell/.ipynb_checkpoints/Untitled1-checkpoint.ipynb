# %%
import pypsa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# C:\Users\Marvin\anaconda3\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# C:\Users\Marvin\anaconda3\lib\site-packages\pypsa\networkclustering.py:16: UserWarning:
#
# The namespace `pypsa.networkclustering` is deprecated and will be removed in PyPSA v0.24. Please use `pypsa.clustering.spatial instead`.

# %% [markdown]
# ![Screenshot%202023-07-12%20170243.png](attachment:Screenshot%202023-07-12%20170243.png)

# %%
# Systemskizze für das Referenzmodell -> Bestimmen welcher Autarkiegrad möglich ist und schauen zu welchen Konditionen überhaupt
# Auch hier können bereits Parameter verändert werden
# Sensivitätsanalyse/ Strompreis abhängigkeit/ größe des Speichers im Verhältnis zum Investiotionslimit etc.pp

# %%
#csv-Datei importieren
csv_datei = "Modellierung_SoSe23.csv"
df_data = pd.read_csv(csv_datei, sep=';', decimal = ',')
df_data
# Out:
#               Zeit  Verbrauch   PV-Ertrag  Netzeinspeisung   Thermische Last   \
# 0     01.01. 00:00    0.016247        0.0               0.0              0.22
# 1     01.01. 01:00    0.016162        0.0               0.0              0.13
# 2     01.01. 02:00    0.016005        0.0               0.0              0.07
# 3     01.01. 03:00    0.166450        0.0               0.0              0.03
# 4     01.01. 04:00    0.016200        0.0               0.0              0.07
# ...            ...         ...        ...               ...               ...
# 8755  31.12. 19:00    1.107500        0.0               0.0              1.69
# 8756  31.12. 20:00    0.261240        0.0               0.0              1.73
# 8757  31.12. 21:00    0.289830        0.0               0.0              1.33
# 8758  31.12. 22:00    0.340810        0.0               0.0              0.81
# 8759  31.12. 23:00    0.016357        0.0               0.0              0.61
#
#       Außentemperatur
# 0               10.70
# 1               10.77
# 2               10.55
# 3               10.44
# 4               10.34
# ...               ...
# 8755             0.83
# 8756             0.51
# 8757             0.20
# 8758            -0.12
# 8759            -0.43
#
# [8760 rows x 6 columns]

# %%
# Bezeichnung der einzelnen Spalten

elektrische_last = df_data['Verbrauch ']
pv_ertrag        = df_data['PV-Ertrag']
thermische_last  = df_data['Thermische Last ']
Temeperatur      = df_data['Außentemperatur']

# %%
# Berechnung des COPs der Wärmepumpe/ Daten vom Prof.

tabelle_x = [-15, -7, 2, 7, 10, 12, 20, 25, 30, 35]
cop_y = [1.7, 2.3, 2.6, 3, 3.2, 3.3, 3.5, 3.7, 3.8, 3.9]

df_data['COP_Tabelle']=np.interp(df_data['Außentemperatur'], 
                                             tabelle_x, cop_y)
wp_el_p_nom = 12.5 #kW
elektr_leistung_y = [14.58, 15.54, 16.7, 18.56, 18.79, 18.87, 19.05, 19.13, 19.36, 19.46]

df_data['WP_p_max_pu'] = np.interp(df_data['Außentemperatur'], 
                                     tabelle_x, elektr_leistung_y)/wp_el_p_nom
df_data
# Out:
#               Zeit  Verbrauch   PV-Ertrag  Netzeinspeisung   Thermische Last   \
# 0     01.01. 00:00    0.016247        0.0               0.0              0.22
# 1     01.01. 01:00    0.016162        0.0               0.0              0.13
# 2     01.01. 02:00    0.016005        0.0               0.0              0.07
# 3     01.01. 03:00    0.166450        0.0               0.0              0.03
# 4     01.01. 04:00    0.016200        0.0               0.0              0.07
# ...            ...         ...        ...               ...               ...
# 8755  31.12. 19:00    1.107500        0.0               0.0              1.69
# 8756  31.12. 20:00    0.261240        0.0               0.0              1.73
# 8757  31.12. 21:00    0.289830        0.0               0.0              1.33
# 8758  31.12. 22:00    0.340810        0.0               0.0              0.81
# 8759  31.12. 23:00    0.016357        0.0               0.0              0.61
#
#       Außentemperatur  COP_Tabelle  WP_p_max_pu
# 0               10.70     3.235000     1.505440
# 1               10.77     3.238500     1.505664
# 2               10.55     3.227500     1.504960
# 3               10.44     3.222000     1.504608
# 4               10.34     3.217000     1.504288
# ...               ...          ...          ...
# 8755             0.83     2.561000     1.323936
# 8756             0.51     2.550333     1.320636
# 8757             0.20     2.540000     1.317440
# 8758            -0.12     2.529333     1.314140
# 8759            -0.43     2.519000     1.310944
#
# [8760 rows x 8 columns]

# %%
WP_p_max_pu      = df_data['WP_p_max_pu']

#Basissystem
pv_p_nom = 10 # in kWp 
pv_p_pu = pv_ertrag/pv_p_nom

#Annahmen für das Ref-Netzwerke

#Marginale Kosten
strompreis_bezug = 0.40                            
strompreis_einspeisung = -0.08
gas_preis = 0.158

#Kapitalkosten pro Jahr pro kW
kapital_kosten_batteriespeicher = 892/12.5              #892€/kWh auf 12.5 Jahre
kapital_kosten_warmwasserspeicher = 53.32/20            #Preis(1965€)/36,85kWh (800l)/ Lebensdauer sind 20 Jahre
kapital_kosten_wp = (25000 / 7.5) / 25
kapital_kosten_pv = (1300*10)/20                        #10kWp Anlage ink. WR für 20000€ auf 20 Jahre

#Wirkungsgrade der Komponenten
wirkungsgrad_batteriespeicher_laden = 0.88        
wirkungsgrad_batteriespeicher_entladen = 0.88           #Wirkungsgrad von wurzel(77%)
selbstentlade_verluste_bs = 0.07
selbstentlade_verluste_ps = 0.08

# %%
summe = df_data['COP_Tabelle'].sum()

anzahl = len(df_data['COP_Tabelle'])

durchschnitt = summe/anzahl 

print(durchschnitt)
# Out:
# 3.1461300646879753

# %%
network = pypsa.Network()
network.set_snapshots(df_data.index)


#Hinzufügung Bus
network.add('Bus', name = 'strom')
network.add('Bus', name = 'batterie')
network.add('Bus', name = 'ueberschuss')
network.add('Bus', name = 'waerme')

#Hinzufügung der Lasten
network.add('Load', name = 'elektrischeLast',bus = 'strom' , p_set  = elektrische_last)
network.add('Load', name = 'thermischelast', bus = 'waerme' , p_set = thermische_last)

#Hinzufügung der Generatoren
network.add('Generator', name = 'PV',              bus = 'ueberschuss', p_nom = pv_p_nom, p_max_pu = pv_p_pu, capital_cost = kapital_kosten_pv)
network.add('Generator', name = 'Netzeinspeisung', bus = 'ueberschuss', marginal_cost = strompreis_einspeisung, sign = -1, p_nom_extendable = True)
network.add('Generator', name = 'Netzbezug',       bus = 'strom', marginal_cost = strompreis_bezug, p_nom = elektrische_last.max())

#Hinzufügung der Speicher
network.add('Store', name = 'battriespeicher',  bus = 'batterie', e_nom_extendable = True, capital_cost = kapital_kosten_batteriespeicher, standing_loss = selbstentlade_verluste_bs, e_cyclic = True)
network.add('Store', name= 'warmwasserspeicher', bus= 'waerme', e_nom_extendable = True ,capital_cost= kapital_kosten_warmwasserspeicher, standing_loss= selbstentlade_verluste_ps)

#Hinzufügung der Links
network.add('Link', name = 'Einspeichern',   bus0 = 'strom',       bus1    = 'batterie', p_nom_extendable = True,  efficiency   = wirkungsgrad_batteriespeicher_laden)
network.add('Link', name = 'Ausspeichern',   bus0 = 'batterie',    bus1    = 'strom',    p_nom_extendable = True, efficiency = wirkungsgrad_batteriespeicher_entladen)
network.add('Link', name = 'eigenverbrauch', bus0 = 'ueberschuss', bus1    = 'strom',    p_nom_extendable = True)
network.add('Link', name = 'waermepumpe',    bus0 = 'strom',       bus1    = 'waerme',   p_nom_extendable = True, efficiency = df_data['COP_Tabelle'], capital_cost= kapital_kosten_wp)

# %%
network.optimize(solver_name = 'gurobi')
# Out:
# INFO:linopy.model: Solve linear problem using Gurobi solver
# Writing constraints.: 100%|██████████| 16/16 [00:01<00:00, 14.91it/s]
# Writing continuous variables.: 100%|██████████| 7/7 [00:00<00:00, 34.12it/s]
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-06-18
# Read LP format model from file C:\Users\Marvin\AppData\Local\Temp\linopy-problem-bpp3bvdx.lp
# Reading time = 0.32 seconds
# obj: 210247 rows, 96367 columns, 385446 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 210247 rows, 96367 columns and 385446 nonzeros
# Model fingerprint: 0x4ab11a9d
# Coefficient statistics:
#   Matrix range     [9e-01, 4e+00]
#   Objective range  [8e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-05, 1e+01]
# Presolve removed 157688 rows and 39469 columns
# Presolve time: 0.17s
# Presolved: 52559 rows, 56898 columns, 153253 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  Dense cols : 3
#  AA' NZ     : 1.139e+05
#  Factor NZ  : 6.570e+05 (roughly 50 MB of memory)
#  Factor Ops : 8.838e+06 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.76429803e+04 -2.97189242e+05  1.35e+01 3.25e-02  3.65e+01     0s
#    1   1.35212753e+04 -1.91482367e+05  2.67e+00 3.15e-01  5.67e+00     0s
#    2   1.12303803e+04 -2.10835396e+04  5.61e-02 1.81e-02  4.92e-01     0s
#    3   4.60092172e+03 -1.33466681e+03  9.13e-04 1.24e-03  6.85e-02     0s
#    4   3.15376498e+03  1.21082302e+02  3.04e-04 3.35e-04  3.28e-02     1s
#    5   2.51928794e+03  5.64470079e+02  1.97e-04 1.53e-04  2.09e-02     1s
#    6   2.09260926e+03  7.95365670e+02  1.32e-04 9.49e-05  1.38e-02     1s
#    7   1.88117624e+03  9.34776804e+02  9.85e-05 6.68e-05  1.00e-02     1s
#    8   1.56640013e+03  1.11987315e+03  4.71e-05 1.70e-05  4.68e-03     1s
#    9   1.42848374e+03  1.19021733e+03  2.71e-05 5.62e-06  2.49e-03     1s
#   10   1.36539294e+03  1.20889849e+03  1.83e-05 3.57e-06  1.63e-03     1s
#   11   1.34265752e+03  1.21764099e+03  1.46e-05 2.62e-06  1.31e-03     1s
#   12   1.33800735e+03  1.22630360e+03  1.40e-05 1.74e-06  1.16e-03     1s
#   13   1.31524164e+03  1.23216159e+03  1.05e-05 4.43e-07  8.66e-04     1s
#   14   1.30358779e+03  1.23346149e+03  8.68e-06 2.10e-07  7.31e-04     1s
#   15   1.29006430e+03  1.23500969e+03  6.66e-06 2.22e-16  5.74e-04     1s
#   16   1.28320640e+03  1.23654178e+03  5.63e-06 2.22e-16  4.86e-04     1s
#   17   1.27642496e+03  1.24008534e+03  4.65e-06 2.22e-16  3.79e-04     1s
#   18   1.27230355e+03  1.24041064e+03  4.03e-06 2.22e-16  3.32e-04     1s
#   19   1.26714207e+03  1.24278402e+03  3.22e-06 1.11e-16  2.54e-04     2s
#   20   1.26413833e+03  1.24358297e+03  2.79e-06 1.67e-16  2.14e-04     2s
#   21   1.25986421e+03  1.24387394e+03  2.11e-06 1.11e-16  1.67e-04     2s
#   22   1.25730430e+03  1.24464656e+03  1.72e-06 1.11e-16  1.32e-04     2s
#   23   1.25536529e+03  1.24527869e+03  1.38e-06 1.82e-16  1.05e-04     2s
#   24   1.25470485e+03  1.24539770e+03  1.26e-06 1.72e-16  9.69e-05     2s
#   25   1.25317308e+03  1.24594743e+03  1.00e-06 1.08e-16  7.52e-05     2s
#   26   1.25264252e+03  1.24610342e+03  9.24e-07 1.02e-16  6.80e-05     2s
#   27   1.25232894e+03  1.24612456e+03  8.71e-07 1.11e-16  6.46e-05     2s
#   28   1.25102028e+03  1.24624533e+03  6.38e-07 9.25e-17  4.97e-05     2s
#
# Barrier performed 28 iterations in 2.11 seconds (0.88 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    22710    1.2471877e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 22710 iterations and 2.19 seconds (5.03 work units)
# Optimal objective  1.247187683e+03
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 96367 primals, 210247 duals
# Objective: 1.25e+03
# Solver model: available
# Solver message: 2
# ('ok', 'optimal')

# %%
network.generators_t.p.plot()
# Out:
# <Axes: xlabel='snapshot'>

# %%
network.loads_t.p.plot()
# Out:
# <Axes: xlabel='snapshot'>

# %%
network.generators_t.p.sum()
# Out:
# Generator
# PV                 11581.694080
# Netzeinspeisung     7832.740293
# Netzbezug           3534.622084
# dtype: float64

# %%
network.stores.e_nom_opt
# Out:
# Store
# battriespeicher        0.030026
# warmwasserspeicher    21.686214
# Name: e_nom_opt, dtype: float64

# %%
#Darstellung der Generatoren-Jahreslinie
network.generators_t.p.plot(subplots=True)
# Out:
# array([<Axes: xlabel='snapshot'>, <Axes: xlabel='snapshot'>,
#        <Axes: xlabel='snapshot'>], dtype=object)

# %%
#Darstellung der Generatoren-Jahreslinie
network.stores_t.e.plot(subplots= True)
# Out:
# array([<Axes: xlabel='snapshot'>, <Axes: xlabel='snapshot'>], dtype=object)

# %%
network.links.p_nom_opt.waermepumpe
# Out:
# 3.0

# %%
#Definieren der zweiten Auswertungsfunktion (Wärmepumpe) ohne Sensitivitäsanaly

def auswertungsfunktion(network, sensitivity_variable = 0): 
    
    #Funktion der laufenden kosten
    
    #Funktion der laufende Kosten
    laufende_kosten_generators = (network.generators_t.p.Netzbezug * network.generators.marginal_cost.Netzbezug  +
                                       network.generators_t.p.PV * network.generators.marginal_cost.PV).sum()
    #Funktion für Investitionskosten
    kapital_kosten_generators = (network.generators.p_nom_opt * network.generators.capital_cost).sum()
    kapital_kosten_links = (network.links.p_nom_opt * network.links.capital_cost).sum()
    kapital_kosten_stores = (network.stores.e_nom_opt *network.stores.capital_cost).sum()
    kapital_kosten_gesamt = (kapital_kosten_stores + kapital_kosten_generators + kapital_kosten_links )
    
    #Gesamtkosten pro Jahr
    total_kosten = (laufende_kosten_generators + kapital_kosten_generators 
    + kapital_kosten_stores + kapital_kosten_links) 
    
       
    #Einspeisevergütung (separat betrachtet von Gesamtkosten)
    einspeise_ertrag = (network.generators_t.p.Netzeinspeisung).sum()*strompreis_einspeisung *-1
    
    
    #Jährliche Einsparung der marginalen Kosten
    bezug_ursprung = (network.loads_t.p.elektrischeLast * network.generators.marginal_cost.Netzbezug + 
                      network.loads_t.p.thermischelast * gas_preis).sum()
    einsparung = bezug_ursprung - laufende_kosten_generators 
    
    #Armotisation
    Anschaffungskosten = (kapital_kosten_generators *20) + (kapital_kosten_links *20) +(kapital_kosten_stores * 20) + (kapital_kosten_links *20)
    Amortisation = Anschaffungskosten/einsparung 
    
    
    #relevante Ausgabewerte
    netzbezug_summe = (network.generators_t.p.Netzbezug).sum()
    netzeinspeisung_summe= (network.generators_t.p.Netzeinspeisung).sum()
    pv_ertrag_summe = (network.generators_t.p.PV).sum()
    einspeicherung_summe = (network.links_t.p0.Einspeichern).sum()
    ausspeicherung_summe = (network.links_t.p0.Ausspeichern).sum()
    Kapazität_Batterie = (network.stores.e_nom_opt.battriespeicher)
    Kapazität_Pufferspeicher =(network.stores.e_nom_opt.warmwasserspeicher*36.85)
    Leistung_wp = (network.links.p_nom_opt.waermepumpe)
    
    
    
    #Werte in Ergebnistabelle auflisten
    results =pd.concat([pd.DataFrame(data=total_kosten, index=[sensitivity_variable],columns=['Kapital- und marginale kosten €/a']),
                         pd.DataFrame(data=einsparung, index=[sensitivity_variable], columns=['Verbrauchseinsparung €/a']),
                         pd.DataFrame(data=laufende_kosten_generators, index=[sensitivity_variable], columns=['Marginale Kosten €/a']),
                         pd.DataFrame(data=bezug_ursprung, index=[sensitivity_variable], columns=['Ursprüngliche Energiekosten €/a']),
                         pd.DataFrame(data=kapital_kosten_gesamt, index=[sensitivity_variable], columns=['Investitionskosten €/a']),
                         pd.DataFrame(data=einspeise_ertrag, index=[sensitivity_variable], columns=['Einspeiseverguetung €/a']),
                         pd.DataFrame(data=Amortisation, index=[sensitivity_variable], columns=['Amortisationsdauer a']),
                         pd.DataFrame(data=netzbezug_summe, index=[sensitivity_variable], columns=['Netzbezug kWh/a']),
                         pd.DataFrame(data=netzeinspeisung_summe, index=[sensitivity_variable], columns=['Netzeinspeisung kWh/a']),
                         pd.DataFrame(data=pv_ertrag_summe, index=[sensitivity_variable], columns=['PV-Ertragssumme kWh/a']),
                         pd.DataFrame(data=einspeicherung_summe, index=[sensitivity_variable], columns=['Einspeicherung kWh/a']),
                         pd.DataFrame(data=ausspeicherung_summe, index=[sensitivity_variable], columns=['Auspeicherung kWh/a']),
                         pd.DataFrame(data=Kapazität_Pufferspeicher, index=[sensitivity_variable], columns=['Pufferspeicherkapazität l']),
                         pd.DataFrame(data=Kapazität_Batterie, index=[sensitivity_variable], columns=['Batteriepeicherkapazität kWh']),
                         pd.DataFrame(data=Leistung_wp, index=[sensitivity_variable], columns=['Leistung Wärmepumpe kW']),],
                         axis = 1)
    

               
    return results

# %%
result = auswertungsfunktion(network)
result
# Out:
#    Kapital- und marginale kosten €/a  Verbrauchseinsparung €/a  \
# 0                        8373.806906               1487.819707
#
#    Marginale Kosten €/a  Ursprüngliche Energiekosten €/a  \
# 0           1413.848834                      2901.668541
#
#    Investitionskosten €/a  Einspeiseverguetung €/a  Amortisationsdauer a  \
# 0             6959.958073               626.619223             98.936155
#
#    Netzbezug kWh/a  Netzeinspeisung kWh/a  PV-Ertragssumme kWh/a  \
# 0      3534.622084            7832.740293            11581.69408
#
#    Einspeicherung kWh/a  Auspeicherung kWh/a  Pufferspeicherkapazität l  \
# 0             13.432103             9.797497                  799.13698
#
#    Batteriepeicherkapazität kWh  Leistung Wärmepumpe kW
# 0                      0.030026                     3.0

# %%
#Ausführung des Standardsnetzwerks
network.optimize(solver_name = 'gurobi')
results = auswertungsfunktion(network, 1)                           


# Call up of the function results, clearing of the results DF
results.drop(results.index, inplace=True)  
results.index.name = 'Strompreis von 0,28 €/kWh bis 1,48 €kWh'


#Preisvariation und Ausgabe der neuen Ergebnisse
for strompreis_bezug in np.flip(np.arange(0.28, 1.48, 0.1)): 
    print(strompreis_bezug)
    network.generators.loc['Netzbezug', 'marginal_cost'] = strompreis_bezug 
    network.optimize(solver_name = 'gurobi')
    results= results.append(auswertungsfunktion(network, strompreis_bezug )) 

network.generators.loc['Netzbezug', 'marginal_cost'] = strompreis_bezug
# Out:
# INFO:linopy.model: Solve linear problem using Gurobi solver
# Writing constraints.: 100%|██████████| 16/16 [00:01<00:00, 14.94it/s]
# Writing continuous variables.: 100%|██████████| 7/7 [00:00<00:00, 35.70it/s]
# Read LP format model from file C:\Users\Marvin\AppData\Local\Temp\linopy-problem-tnexaq1v.lp
# Reading time = 0.32 seconds
# obj: 210247 rows, 96367 columns, 385446 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 210247 rows, 96367 columns and 385446 nonzeros
# Model fingerprint: 0x4ab11a9d
# Coefficient statistics:
#   Matrix range     [9e-01, 4e+00]
#   Objective range  [8e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-05, 1e+01]
# Presolve removed 157688 rows and 39469 columns
# Presolve time: 0.16s
# Presolved: 52559 rows, 56898 columns, 153253 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  Dense cols : 3
#  AA' NZ     : 1.139e+05
#  Factor NZ  : 6.570e+05 (roughly 50 MB of memory)
#  Factor Ops : 8.838e+06 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.76429803e+04 -2.97189242e+05  1.35e+01 3.25e-02  3.65e+01     0s
#    1   1.35212753e+04 -1.91482367e+05  2.67e+00 3.15e-01  5.67e+00     0s
#    2   1.12303803e+04 -2.10835396e+04  5.61e-02 1.81e-02  4.92e-01     0s
#    3   4.60092172e+03 -1.33466681e+03  9.13e-04 1.24e-03  6.85e-02     0s
#    4   3.15376498e+03  1.21082302e+02  3.04e-04 3.35e-04  3.28e-02     1s
#    5   2.51928794e+03  5.64470079e+02  1.97e-04 1.53e-04  2.09e-02     1s
#    6   2.09260926e+03  7.95365670e+02  1.32e-04 9.49e-05  1.38e-02     1s
#    7   1.88117624e+03  9.34776804e+02  9.85e-05 6.68e-05  1.00e-02     1s
#    8   1.56640013e+03  1.11987315e+03  4.71e-05 1.70e-05  4.68e-03     1s
#    9   1.42848374e+03  1.19021733e+03  2.71e-05 5.62e-06  2.49e-03     1s
#   10   1.36539294e+03  1.20889849e+03  1.83e-05 3.57e-06  1.63e-03     1s
#   11   1.34265752e+03  1.21764099e+03  1.46e-05 2.62e-06  1.31e-03     1s
#   12   1.33800735e+03  1.22630360e+03  1.40e-05 1.74e-06  1.16e-03     1s
#   13   1.31524164e+03  1.23216159e+03  1.05e-05 4.43e-07  8.66e-04     1s
#   14   1.30358779e+03  1.23346149e+03  8.68e-06 2.10e-07  7.31e-04     1s
#   15   1.29006430e+03  1.23500969e+03  6.66e-06 2.22e-16  5.74e-04     1s
#   16   1.28320640e+03  1.23654178e+03  5.63e-06 2.22e-16  4.86e-04     1s
#   17   1.27642496e+03  1.24008534e+03  4.65e-06 2.22e-16  3.79e-04     1s
#   18   1.27230355e+03  1.24041064e+03  4.03e-06 2.22e-16  3.32e-04     1s
#   19   1.26714207e+03  1.24278402e+03  3.22e-06 1.11e-16  2.54e-04     1s
#   20   1.26413833e+03  1.24358297e+03  2.79e-06 1.67e-16  2.14e-04     2s
#   21   1.25986421e+03  1.24387394e+03  2.11e-06 1.11e-16  1.67e-04     2s
#   22   1.25730430e+03  1.24464656e+03  1.72e-06 1.11e-16  1.32e-04     2s
#   23   1.25536529e+03  1.24527869e+03  1.38e-06 1.82e-16  1.05e-04     2s
#   24   1.25470485e+03  1.24539770e+03  1.26e-06 1.72e-16  9.69e-05     2s
#   25   1.25317308e+03  1.24594743e+03  1.00e-06 1.08e-16  7.52e-05     2s
#   26   1.25264252e+03  1.24610342e+03  9.24e-07 1.02e-16  6.80e-05     2s
#   27   1.25232894e+03  1.24612456e+03  8.71e-07 1.11e-16  6.46e-05     2s
#   28   1.25102028e+03  1.24624533e+03  6.38e-07 9.25e-17  4.97e-05     2s
#   29   1.25022533e+03  1.24650287e+03  5.08e-07 5.81e-17  3.87e-05     2s
#   30   1.24978421e+03  1.24658964e+03  4.41e-07 5.94e-17  3.32e-05     2s
#
# Barrier performed 30 iterations in 2.17 seconds (0.92 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    22710    1.2471877e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 22710 iterations and 2.24 seconds (5.03 work units)
# Optimal objective  1.247187683e+03
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 96367 primals, 210247 duals
# Objective: 1.25e+03
# Solver model: available
# Solver message: 2
# 1.3799999999999997
# INFO:linopy.model: Solve linear problem using Gurobi solver
# Writing constraints.: 100%|██████████| 16/16 [00:01<00:00, 15.39it/s]
# Writing continuous variables.: 100%|██████████| 7/7 [00:00<00:00, 36.00it/s]
# Read LP format model from file C:\Users\Marvin\AppData\Local\Temp\linopy-problem-ll24fu_v.lp
# Reading time = 0.32 seconds
# obj: 210247 rows, 96367 columns, 385446 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 210247 rows, 96367 columns and 385446 nonzeros
# Model fingerprint: 0x13350d64
# Coefficient statistics:
#   Matrix range     [9e-01, 4e+00]
#   Objective range  [8e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-05, 1e+01]
# Presolve removed 157688 rows and 39469 columns
# Presolve time: 0.16s
# Presolved: 52559 rows, 56898 columns, 153253 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  Dense cols : 3
#  AA' NZ     : 1.139e+05
#  Factor NZ  : 6.570e+05 (roughly 50 MB of memory)
#  Factor Ops : 8.838e+06 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   8.93773528e+04 -5.94560793e+05  1.36e+01 1.11e-01  7.39e+01     0s
#    1   3.99030148e+04 -3.81396023e+05  2.70e+00 6.35e-01  1.15e+01     0s
#    2   3.12599542e+04 -3.18017716e+04  5.77e-02 3.13e-02  9.25e-01     0s
#    3   1.51741351e+04 -2.73022359e+03  4.84e-03 3.71e-03  2.07e-01     0s
#    4   9.49839645e+03  1.08703064e+03  2.44e-03 8.74e-04  9.18e-02     1s
#    5   7.16719005e+03  2.08018312e+03  1.44e-03 3.86e-04  5.49e-02     1s
#    6   6.13931541e+03  2.58775912e+03  9.66e-04 2.56e-04  3.81e-02     1s
#    7   5.58009345e+03  3.02768491e+03  6.55e-04 1.55e-04  2.72e-02     1s
#    8   4.71497958e+03  3.39418384e+03  3.16e-04 6.23e-05  1.40e-02     1s
#    9   4.31412037e+03  3.69463438e+03  1.50e-04 1.78e-05  6.55e-03     1s
#   10   4.13529524e+03  3.82571296e+03  8.06e-05 6.70e-06  3.26e-03     1s
#   11   4.04023670e+03  3.86804140e+03  4.40e-05 2.59e-06  1.81e-03     1s
#   12   3.99913429e+03  3.89163847e+03  2.80e-05 7.69e-07  1.13e-03     1s
#   13   3.96898327e+03  3.90532835e+03  1.65e-05 2.39e-08  6.68e-04     1s
#   14   3.95132385e+03  3.91370066e+03  1.01e-05 6.66e-16  3.94e-04     1s
#   15   3.94041429e+03  3.91728769e+03  6.08e-06 6.66e-16  2.42e-04     1s
#   16   3.93005627e+03  3.92076037e+03  2.31e-06 2.62e-16  9.73e-05     1s
#   17   3.92669041e+03  3.92203202e+03  1.11e-06 2.52e-16  4.87e-05     1s
#   18   3.92425628e+03  3.92290995e+03  2.60e-07 2.78e-16  1.41e-05     1s
#   19   3.92350448e+03  3.92331050e+03  2.71e-08 3.33e-16  2.03e-06     1s
#   20   3.92341066e+03  3.92339528e+03  2.26e-09 3.99e-16  1.60e-07     2s
#   21   3.92340171e+03  3.92340018e+03  6.31e-10 2.58e-12  1.59e-08     2s
#   22   3.92340054e+03  3.92340038e+03  2.13e-09 1.17e-12  1.63e-09     2s
#   23   3.92340038e+03  3.92340038e+03  4.24e-11 2.58e-12  2.39e-12     2s
#
# Barrier solved model in 23 iterations and 1.67 seconds (0.75 work units)
# Optimal objective 3.92340038e+03
#
# Crossover log...
#
#     4680 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.5177443e-13      2s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4683    3.9234004e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 4683 iterations and 1.85 seconds (0.85 work units)
# Optimal objective  3.923400383e+03
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 96367 primals, 210247 duals
# Objective: 3.92e+03
# Solver model: available
# Solver message: 2
#
# C:\Users\Marvin\AppData\Local\Temp\ipykernel_37456\1490851207.py:16: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# 1.2799999999999998
# INFO:linopy.model: Solve linear problem using Gurobi solver
# Writing constraints.: 100%|██████████| 16/16 [00:01<00:00, 15.64it/s]
# Writing continuous variables.: 100%|██████████| 7/7 [00:00<00:00, 35.53it/s]
# Read LP format model from file C:\Users\Marvin\AppData\Local\Temp\linopy-problem-x2lwbhbk.lp
# Reading time = 0.32 seconds
# obj: 210247 rows, 96367 columns, 385446 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 210247 rows, 96367 columns and 385446 nonzeros
# Model fingerprint: 0xcec527f8
# Coefficient statistics:
#   Matrix range     [9e-01, 4e+00]
#   Objective range  [8e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-05, 1e+01]
# Presolve removed 157688 rows and 39469 columns
# Presolve time: 0.17s
# Presolved: 52559 rows, 56898 columns, 153253 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  Dense cols : 3
#  AA' NZ     : 1.139e+05
#  Factor NZ  : 6.570e+05 (roughly 50 MB of memory)
#  Factor Ops : 8.838e+06 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   8.30791054e+04 -5.71627789e+05  1.36e+01 1.03e-01  7.10e+01     0s
#    1   3.72241228e+04 -3.66836052e+05  2.70e+00 6.10e-01  1.11e+01     0s
#    2   2.92934681e+04 -3.14187562e+04  5.77e-02 3.05e-02  8.94e-01     0s
#    3   1.41477202e+04 -2.67185739e+03  4.09e-03 3.35e-03  1.95e-01     1s
#    4   8.96034956e+03  9.68564213e+02  2.18e-03 9.08e-04  8.73e-02     1s
#    5   6.79818076e+03  1.95396656e+03  1.30e-03 3.59e-04  5.22e-02     1s
#    6   5.72231452e+03  2.42832312e+03  8.39e-04 2.55e-04  3.53e-02     1s
#    7   5.01476708e+03  2.81929768e+03  5.13e-04 1.50e-04  2.34e-02     1s
#    8   4.40214571e+03  3.13365465e+03  2.78e-04 7.52e-05  1.35e-02     1s
#    9   4.03721139e+03  3.47379248e+03  1.29e-04 1.91e-05  5.96e-03     1s
#   10   3.86735348e+03  3.57801042e+03  6.82e-05 5.10e-06  3.05e-03     1s
#   11   3.77384803e+03  3.61566920e+03  3.51e-05 2.00e-06  1.67e-03     1s
#   12   3.73109682e+03  3.64201456e+03  2.00e-05 3.15e-07  9.38e-04     1s
#   13   3.70558468e+03  3.65293697e+03  1.08e-05 1.98e-07  5.55e-04     1s
#   14   3.68861172e+03  3.66772519e+03  4.97e-06 5.55e-16  2.19e-04     1s
#   15   3.68191475e+03  3.66988380e+03  2.82e-06 2.73e-16  1.26e-04     1s
#   16   3.67566049e+03  3.67171014e+03  8.22e-07 2.47e-16  4.14e-05     1s
#   17   3.67403483e+03  3.67236391e+03  3.25e-07 3.19e-16  1.75e-05     1s
#   18   3.67324697e+03  3.67273978e+03  9.47e-08 2.53e-16  5.30e-06     1s
#   19   3.67291889e+03  3.67287771e+03  5.71e-09 3.95e-16  4.29e-07     2s
#   20   3.67289442e+03  3.67289323e+03  5.86e-10 1.65e-12  1.24e-08     2s
#   21   3.67289378e+03  3.67289378e+03  1.44e-09 2.07e-12  4.17e-11     2s
#
# Barrier solved model in 21 iterations and 1.65 seconds (0.71 work units)
# Optimal objective 3.67289378e+03
#
# Crossover log...
#
#     4760 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#        3 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.0435056e-13      2s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4766    3.6728938e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 4766 iterations and 1.87 seconds (0.82 work units)
# Optimal objective  3.672893782e+03
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 96367 primals, 210247 duals
# Objective: 3.67e+03
# Solver model: available
# Solver message: 2
#
# C:\Users\Marvin\AppData\Local\Temp\ipykernel_37456\1490851207.py:16: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# 1.1799999999999997
# INFO:linopy.model: Solve linear problem using Gurobi solver
# Writing constraints.: 100%|██████████| 16/16 [00:01<00:00, 15.10it/s]
# Writing continuous variables.: 100%|██████████| 7/7 [00:00<00:00, 36.18it/s]
# Read LP format model from file C:\Users\Marvin\AppData\Local\Temp\linopy-problem-r7j9hyt8.lp
# Reading time = 0.31 seconds
# obj: 210247 rows, 96367 columns, 385446 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 210247 rows, 96367 columns and 385446 nonzeros
# Model fingerprint: 0x5e4b101f
# Coefficient statistics:
#   Matrix range     [9e-01, 4e+00]
#   Objective range  [8e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-05, 1e+01]
# Presolve removed 157688 rows and 39469 columns
# Presolve time: 0.15s
# Presolved: 52559 rows, 56898 columns, 153253 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  Dense cols : 3
#  AA' NZ     : 1.139e+05
#  Factor NZ  : 6.570e+05 (roughly 50 MB of memory)
#  Factor Ops : 8.838e+06 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7.67807781e+04 -5.47679075e+05  1.36e+01 9.51e-02  6.80e+01     0s
#    1   3.45426706e+04 -3.51616229e+05  2.70e+00 5.85e-01  1.06e+01     0s
#    2   2.73124850e+04 -3.09374461e+04  5.77e-02 2.97e-02  8.62e-01     0s
#    3   1.31379301e+04 -2.58888227e+03  3.27e-03 3.16e-03  1.82e-01     0s
#    4   8.33203631e+03  8.56961593e+02  1.75e-03 9.23e-04  8.16e-02     1s
#    5   6.30635451e+03  1.76181607e+03  1.04e-03 3.84e-04  4.90e-02     1s
#    6   5.19735146e+03  2.29007014e+03  6.18e-04 2.01e-04  3.12e-02     1s
#    7   4.63769462e+03  2.74598652e+03  3.94e-04 1.18e-04  2.02e-02     1s
#    8   4.02533296e+03  3.15802771e+03  1.95e-04 3.11e-05  9.14e-03     1s
#    9   3.69494627e+03  3.32670666e+03  8.47e-05 3.84e-06  3.86e-03     1s
#   10   3.57185004e+03  3.37119192e+03  4.63e-05 4.22e-08  2.10e-03     1s
#   11   3.51492741e+03  3.39568826e+03  2.88e-05 1.78e-15  1.25e-03     1s
#   12   3.47853456e+03  3.40737035e+03  1.74e-05 8.88e-16  7.42e-04     1s
#   13   3.45372324e+03  3.41404947e+03  9.73e-06 6.66e-16  4.13e-04     1s
#   14   3.42980880e+03  3.41703180e+03  2.57e-06 2.58e-16  1.33e-04     1s
#   15   3.42466454e+03  3.41887960e+03  1.09e-06 2.23e-16  6.04e-05     1s
#   16   3.42200304e+03  3.42008902e+03  3.48e-07 2.68e-16  2.00e-05     1s
#   17   3.42154513e+03  3.42039985e+03  2.29e-07 2.64e-16  1.19e-05     1s
#   18   3.42097791e+03  3.42053787e+03  8.59e-08 2.62e-16  4.58e-06     1s
#   19   3.42067507e+03  3.42062601e+03  9.57e-09 3.33e-16  5.10e-07     1s
#   20   3.42063430e+03  3.42063190e+03  1.09e-09 3.33e-16  2.49e-08     1s
#   21   3.42063297e+03  3.42063281e+03  3.83e-10 2.73e-16  1.67e-09     2s
#   22   3.42063292e+03  3.42063292e+03  2.12e-10 8.03e-13  5.73e-12     2s
#
# Barrier solved model in 22 iterations and 1.60 seconds (0.73 work units)
# Optimal objective 3.42063292e+03
#
# Crossover log...
#
#     4865 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#        1 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.3493373e-13      2s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4869    3.4206329e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 4869 iterations and 1.78 seconds (0.84 work units)
# Optimal objective  3.420632917e+03
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 96367 primals, 210247 duals
# Objective: 3.42e+03
# Solver model: available
# Solver message: 2
#
# C:\Users\Marvin\AppData\Local\Temp\ipykernel_37456\1490851207.py:16: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# 1.0799999999999998
# INFO:linopy.model: Solve linear problem using Gurobi solver
# Writing constraints.: 100%|██████████| 16/16 [00:01<00:00, 15.50it/s]
# Writing continuous variables.: 100%|██████████| 7/7 [00:00<00:00, 36.26it/s]
# Read LP format model from file C:\Users\Marvin\AppData\Local\Temp\linopy-problem-zzvfbtyt.lp
# Reading time = 0.32 seconds
# obj: 210247 rows, 96367 columns, 385446 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 210247 rows, 96367 columns and 385446 nonzeros
# Model fingerprint: 0xbf016ae1
# Coefficient statistics:
#   Matrix range     [9e-01, 4e+00]
#   Objective range  [8e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-05, 1e+01]
# Presolve removed 157688 rows and 39469 columns
# Presolve time: 0.17s
# Presolved: 52559 rows, 56898 columns, 153253 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  Dense cols : 3
#  AA' NZ     : 1.139e+05
#  Factor NZ  : 6.570e+05 (roughly 50 MB of memory)
#  Factor Ops : 8.838e+06 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7.04823473e+04 -5.22572283e+05  1.36e+01 8.70e-02  6.48e+01     0s
#    1   3.18604888e+04 -3.35643942e+05  2.69e+00 5.58e-01  1.01e+01     0s
#    2   2.53164222e+04 -3.03580610e+04  5.75e-02 2.88e-02  8.27e-01     0s
#    3   1.21058952e+04 -2.46669983e+03  2.30e-03 2.98e-03  1.69e-01     1s
#    4   7.58912138e+03  7.17450873e+02  1.16e-03 8.77e-04  7.52e-02     1s
#    5   5.75399185e+03  1.52054295e+03  6.93e-04 4.11e-04  4.58e-02     1s
#    6   4.64074232e+03  2.03534439e+03  3.56e-04 2.58e-04  2.80e-02     1s
#    7   4.14590426e+03  2.45749708e+03  2.28e-04 1.37e-04  1.81e-02     1s
#    8   3.62568126e+03  2.88628659e+03  9.93e-05 3.26e-05  7.85e-03     1s
#    9   3.35805202e+03  3.04927552e+03  3.96e-05 8.58e-06  3.26e-03     1s
#   10   3.27054005e+03  3.11994096e+03  2.10e-05 1.56e-06  1.58e-03     1s
#   11   3.22637672e+03  3.14485636e+03  1.21e-05 6.66e-16  8.55e-04     1s
#   12   3.19501649e+03  3.15498494e+03  5.64e-06 4.44e-16  4.19e-04     1s
#   13   3.18279282e+03  3.16030228e+03  3.19e-06 2.22e-16  2.35e-04     1s
#   14   3.17199028e+03  3.16407833e+03  1.10e-06 2.22e-16  8.26e-05     1s
#   15   3.16827427e+03  3.16502796e+03  4.08e-07 2.28e-16  3.39e-05     1s
#   16   3.16671148e+03  3.16564129e+03  1.32e-07 2.62e-16  1.12e-05     1s
#   17   3.16614358e+03  3.16579217e+03  3.38e-08 2.45e-16  3.67e-06     1s
#   18   3.16596605e+03  3.16591236e+03  4.59e-09 2.76e-16  5.60e-07     1s
#   19   3.16593057e+03  3.16592962e+03  2.18e-10 7.01e-13  9.89e-09     1s
#   20   3.16593017e+03  3.16593017e+03  6.59e-09 2.63e-14  5.60e-11     2s
#
# Barrier solved model in 20 iterations and 1.54 seconds (0.70 work units)
# Optimal objective 3.16593017e+03
#
# Crossover log...
#
#     4996 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#        6 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.5226709e-13      2s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5005    3.1659302e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 5005 iterations and 1.74 seconds (0.81 work units)
# Optimal objective  3.165930171e+03
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 96367 primals, 210247 duals
# Objective: 3.17e+03
# Solver model: available
# Solver message: 2
#
# C:\Users\Marvin\AppData\Local\Temp\ipykernel_37456\1490851207.py:16: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# 0.9799999999999999
# INFO:linopy.model: Solve linear problem using Gurobi solver
# Writing constraints.: 100%|██████████| 16/16 [00:01<00:00, 15.11it/s]
# Writing continuous variables.: 100%|██████████| 7/7 [00:00<00:00, 35.24it/s]
# Read LP format model from file C:\Users\Marvin\AppData\Local\Temp\linopy-problem-f3vrs7bk.lp
# Reading time = 0.33 seconds
# obj: 210247 rows, 96367 columns, 385446 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 210247 rows, 96367 columns and 385446 nonzeros
# Model fingerprint: 0xa2ef9fd0
# Coefficient statistics:
#   Matrix range     [9e-01, 4e+00]
#   Objective range  [8e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-05, 1e+01]
# Presolve removed 157688 rows and 39469 columns
# Presolve time: 0.18s
# Presolved: 52559 rows, 56898 columns, 153253 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  Dense cols : 3
#  AA' NZ     : 1.139e+05
#  Factor NZ  : 6.570e+05 (roughly 50 MB of memory)
#  Factor Ops : 8.838e+06 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.41837788e+04 -4.96128309e+05  1.36e+01 7.90e-02  6.15e+01     0s
#    1   2.91753014e+04 -3.18802612e+05  2.69e+00 5.29e-01  9.56e+00     0s
#    2   2.33043120e+04 -2.96541520e+04  5.74e-02 2.77e-02  7.90e-01     0s
#    3   1.10437340e+04 -2.31067444e+03  1.22e-03 2.75e-03  1.55e-01     1s
#    4   6.89675710e+03  5.96887229e+02  5.95e-04 8.35e-04  6.89e-02     1s
#    5   5.23207564e+03  1.35623259e+03  3.48e-04 3.82e-04  4.19e-02     1s
#    6   4.91147795e+03  1.83092973e+03  2.93e-04 2.46e-04  3.30e-02     1s
#    7   4.08377740e+03  2.13751117e+03  1.65e-04 1.43e-04  2.09e-02     1s
#    8   3.49158716e+03  2.57008591e+03  7.81e-05 4.36e-05  9.80e-03     1s
#    9   3.12733602e+03  2.77565002e+03  2.69e-05 1.05e-05  3.72e-03     1s
#   10   3.01866025e+03  2.85858314e+03  1.31e-05 3.30e-06  1.69e-03     1s
#   11   2.96542278e+03  2.88177922e+03  6.50e-06 8.13e-07  8.80e-04     1s
#   12   2.93435466e+03  2.89159936e+03  2.78e-06 4.92e-07  4.51e-04     1s
#   13   2.92374101e+03  2.89994416e+03  1.57e-06 2.24e-07  2.51e-04     1s
#   14   2.91502651e+03  2.90612482e+03  6.38e-07 3.67e-08  9.34e-05     1s
#   15   2.91207693e+03  2.90745347e+03  3.33e-07 1.58e-16  4.84e-05     1s
#   16   2.90999364e+03  2.90830644e+03  1.17e-07 1.53e-16  1.76e-05     1s
#   17   2.90924514e+03  2.90854477e+03  4.49e-08 1.46e-16  7.32e-06     1s
#   18   2.90878219e+03  2.90871834e+03  1.65e-09 1.93e-16  6.70e-07     1s
#   19   2.90875725e+03  2.90875501e+03  4.20e-10 2.04e-16  2.35e-08     2s
#   20   2.90875690e+03  2.90875681e+03  8.15e-11 1.67e-16  8.65e-10     2s
#   21   2.90875689e+03  2.90875689e+03  2.36e-10 6.18e-13  8.96e-12     2s
#
# Barrier solved model in 21 iterations and 1.69 seconds (0.71 work units)
# Optimal objective 2.90875689e+03
#
# Crossover log...
#
#     5128 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#        1 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.9484067e-13      2s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5132    2.9087569e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 5132 iterations and 1.90 seconds (0.82 work units)
# Optimal objective  2.908756893e+03
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 96367 primals, 210247 duals
# Objective: 2.91e+03
# Solver model: available
# Solver message: 2
#
# C:\Users\Marvin\AppData\Local\Temp\ipykernel_37456\1490851207.py:16: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# 0.8799999999999999
# INFO:linopy.model: Solve linear problem using Gurobi solver
# Writing constraints.: 100%|██████████| 16/16 [00:01<00:00, 15.19it/s]
# Writing continuous variables.: 100%|██████████| 7/7 [00:00<00:00, 35.93it/s]
# Read LP format model from file C:\Users\Marvin\AppData\Local\Temp\linopy-problem-g3_m124b.lp
# Reading time = 0.32 seconds
# obj: 210247 rows, 96367 columns, 385446 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 210247 rows, 96367 columns and 385446 nonzeros
# Model fingerprint: 0xe4ba6044
# Coefficient statistics:
#   Matrix range     [9e-01, 4e+00]
#   Objective range  [8e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-05, 1e+01]
# Presolve removed 157688 rows and 39469 columns
# Presolve time: 0.16s
# Presolved: 52559 rows, 56898 columns, 153253 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  Dense cols : 3
#  AA' NZ     : 1.139e+05
#  Factor NZ  : 6.570e+05 (roughly 50 MB of memory)
#  Factor Ops : 8.838e+06 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.78850216e+04 -4.68116492e+05  1.36e+01 7.10e-02  5.79e+01     0s
#    1   2.64867620e+04 -3.00942216e+05  2.69e+00 4.99e-01  9.01e+00     0s
#    2   2.12750914e+04 -2.88034811e+04  5.72e-02 2.66e-02  7.51e-01     0s
#    3   1.02279804e+04 -2.23001369e+03  1.17e-03 2.51e-03  1.45e-01     0s
#    4   6.29424515e+03  4.84889913e+02  3.37e-04 7.91e-04  6.35e-02     1s
#    5   4.80805092e+03  1.18026498e+03  1.93e-04 3.73e-04  3.92e-02     1s
#    6   4.60164299e+03  1.69451226e+03  1.72e-04 2.39e-04  3.11e-02     1s
#    7   3.59193401e+03  2.03927436e+03  8.03e-05 1.36e-04  1.66e-02     1s
#    8   3.22624523e+03  2.42200707e+03  4.96e-05 3.43e-05  8.47e-03     1s
#    9   2.85078863e+03  2.54858216e+03  1.64e-05 3.56e-06  3.18e-03     1s
#   10   2.73407653e+03  2.60758697e+03  6.82e-06 1.33e-15  1.33e-03     1s
#   11   2.69710102e+03  2.62460088e+03  3.80e-06 8.88e-16  7.60e-04     1s
#   12   2.67024736e+03  2.63611930e+03  1.66e-06 4.44e-16  3.58e-04     1s
#   13   2.65781583e+03  2.64194726e+03  7.27e-07 4.44e-16  1.66e-04     1s
#   14   2.65091589e+03  2.64558377e+03  2.28e-07 1.44e-16  5.58e-05     1s
#   15   2.64892259e+03  2.64647196e+03  9.51e-08 1.34e-16  2.56e-05     1s
#   16   2.64797198e+03  2.64708689e+03  3.50e-08 1.91e-16  9.24e-06     1s
#   17   2.64753841e+03  2.64718713e+03  9.29e-09 1.67e-16  3.68e-06     1s
#   18   2.64740045e+03  2.64733926e+03  1.78e-09 1.82e-16  6.38e-07     1s
#   19   2.64736699e+03  2.64735749e+03  3.74e-10 1.75e-16  9.91e-08     1s
#   20   2.64736387e+03  2.64736203e+03  2.05e-09 1.55e-16  1.92e-08     2s
#   21   2.64736384e+03  2.64736364e+03  1.79e-10 2.22e-16  2.09e-09     2s
#   22   2.64736380e+03  2.64736380e+03  1.43e-10 2.83e-12  1.63e-13     2s
#
# Barrier solved model in 22 iterations and 1.61 seconds (0.73 work units)
# Optimal objective 2.64736380e+03
#
# Crossover log...
#
#     5300 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.5721452e-13      2s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5303    2.6473638e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 5303 iterations and 1.80 seconds (0.84 work units)
# Optimal objective  2.647363797e+03
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 96367 primals, 210247 duals
# Objective: 2.65e+03
# Solver model: available
# Solver message: 2
#
# C:\Users\Marvin\AppData\Local\Temp\ipykernel_37456\1490851207.py:16: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# 0.7799999999999999
# INFO:linopy.model: Solve linear problem using Gurobi solver
# Writing constraints.: 100%|██████████| 16/16 [00:01<00:00, 15.63it/s]
# Writing continuous variables.: 100%|██████████| 7/7 [00:00<00:00, 36.15it/s]
# Read LP format model from file C:\Users\Marvin\AppData\Local\Temp\linopy-problem-bjaa062e.lp
# Reading time = 0.32 seconds
# obj: 210247 rows, 96367 columns, 385446 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 210247 rows, 96367 columns and 385446 nonzeros
# Model fingerprint: 0x70639321
# Coefficient statistics:
#   Matrix range     [9e-01, 4e+00]
#   Objective range  [8e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-05, 1e+01]
# Presolve removed 157688 rows and 39469 columns
# Presolve time: 0.16s
# Presolved: 52559 rows, 56898 columns, 153253 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  Dense cols : 3
#  AA' NZ     : 1.139e+05
#  Factor NZ  : 6.570e+05 (roughly 50 MB of memory)
#  Factor Ops : 8.838e+06 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.15859960e+04 -4.38231080e+05  1.36e+01 6.30e-02  5.42e+01     0s
#    1   2.37946128e+04 -2.81863824e+05  2.69e+00 4.67e-01  8.43e+00     0s
#    2   1.92272874e+04 -2.77732239e+04  5.70e-02 2.53e-02  7.08e-01     0s
#    3   9.00658642e+03 -1.84368569e+03  1.13e-03 2.03e-03  1.26e-01     0s
#    4   5.43033053e+03  4.49751046e+02  2.93e-04 7.28e-04  5.45e-02     1s
#    5   4.40295919e+03  9.54346097e+02  1.97e-04 4.64e-04  3.73e-02     1s
#    6   4.12273972e+03  1.13642171e+03  1.63e-04 4.04e-04  3.23e-02     1s
#    7   3.50002029e+03  1.67379748e+03  1.06e-04 1.72e-04  1.96e-02     1s
#    8   2.93224188e+03  2.02146852e+03  4.99e-05 6.76e-05  9.72e-03     1s
#    9   2.64317744e+03  2.24394932e+03  2.21e-05 1.06e-05  4.22e-03     1s
#   10   2.50766102e+03  2.33043987e+03  1.04e-05 1.13e-06  1.86e-03     1s
#   11   2.44378561e+03  2.34830596e+03  5.11e-06 6.25e-07  1.01e-03     1s
#   12   2.41069089e+03  2.36272170e+03  2.31e-06 8.88e-16  5.06e-04     1s
#   13   2.39396455e+03  2.37344454e+03  9.46e-07 3.33e-16  2.16e-04     1s
#   14   2.38529678e+03  2.37917069e+03  2.84e-07 2.22e-16  6.43e-05     1s
#   15   2.38299915e+03  2.38018488e+03  1.18e-07 1.67e-16  2.95e-05     1s
#   16   2.38162247e+03  2.38090875e+03  2.42e-08 1.55e-16  7.48e-06     1s
#   17   2.38137317e+03  2.38108509e+03  9.17e-09 1.29e-16  3.02e-06     1s
#   18   2.38121996e+03  2.38119860e+03  3.84e-10 1.70e-16  2.24e-07     1s
#   19   2.38121358e+03  2.38121288e+03  5.63e-10 2.36e-12  7.29e-09     1s
#   20   2.38121334e+03  2.38121334e+03  3.76e-11 1.32e-12  7.83e-12     2s
#
# Barrier solved model in 20 iterations and 1.52 seconds (0.70 work units)
# Optimal objective 2.38121334e+03
#
# Crossover log...
#
#     5536 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#        1 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 9.4525082e-14      2s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5540    2.3812133e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 5540 iterations and 1.73 seconds (0.81 work units)
# Optimal objective  2.381213341e+03
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 96367 primals, 210247 duals
# Objective: 2.38e+03
# Solver model: available
# Solver message: 2
#
# C:\Users\Marvin\AppData\Local\Temp\ipykernel_37456\1490851207.py:16: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# 0.6799999999999999
# INFO:linopy.model: Solve linear problem using Gurobi solver
# Writing constraints.: 100%|██████████| 16/16 [00:01<00:00, 15.23it/s]
# Writing continuous variables.: 100%|██████████| 7/7 [00:00<00:00, 35.78it/s]
# Read LP format model from file C:\Users\Marvin\AppData\Local\Temp\linopy-problem-uz84vyf3.lp
# Reading time = 0.31 seconds
# obj: 210247 rows, 96367 columns, 385446 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 210247 rows, 96367 columns and 385446 nonzeros
# Model fingerprint: 0x3ab7a912
# Coefficient statistics:
#   Matrix range     [9e-01, 4e+00]
#   Objective range  [8e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-05, 1e+01]
# Presolve removed 157688 rows and 39469 columns
# Presolve time: 0.16s
# Presolved: 52559 rows, 56898 columns, 153253 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  Dense cols : 3
#  AA' NZ     : 1.139e+05
#  Factor NZ  : 6.570e+05 (roughly 50 MB of memory)
#  Factor Ops : 8.838e+06 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.52865701e+04 -4.06051777e+05  1.36e+01 5.49e-02  5.01e+01     0s
#    1   2.10984107e+04 -2.61293306e+05  2.68e+00 4.32e-01  7.80e+00     0s
#    2   1.71589367e+04 -2.65155148e+04  5.68e-02 2.38e-02  6.60e-01     0s
#    3   7.97970421e+03 -1.81713311e+03  1.08e-03 1.96e-03  1.14e-01     0s
#    4   4.66054630e+03  3.35990615e+02  2.69e-04 6.39e-04  4.74e-02     1s
#    5   3.79139269e+03  5.84624218e+02  1.77e-04 5.24e-04  3.50e-02     1s
#    6   3.71641425e+03  8.01595542e+02  1.67e-04 4.40e-04  3.17e-02     1s
#    7   3.11408929e+03  1.46517027e+03  9.44e-05 1.73e-04  1.77e-02     1s
#    8   2.66806694e+03  1.85473940e+03  5.14e-05 4.64e-05  8.60e-03     1s
#    9   2.31566296e+03  2.02981883e+03  1.79e-05 3.25e-06  3.00e-03     1s
#   10   2.18592521e+03  2.07692474e+03  6.44e-06 8.88e-16  1.14e-03     1s
#   11   2.15609376e+03  2.08652377e+03  3.97e-06 8.88e-16  7.28e-04     1s
#   12   2.13407465e+03  2.09706532e+03  2.16e-06 4.44e-16  3.87e-04     1s
#   13   2.11958155e+03  2.10135277e+03  9.65e-07 2.22e-16  1.91e-04     1s
#   14   2.11251783e+03  2.10503685e+03  3.77e-07 2.22e-16  7.82e-05     1s
#   15   2.10977297e+03  2.10623499e+03  1.66e-07 1.11e-16  3.70e-05     1s
#   16   2.10821014e+03  2.10713218e+03  5.02e-08 1.34e-16  1.13e-05     1s
#   17   2.10773564e+03  2.10733416e+03  1.59e-08 1.29e-16  4.19e-06     1s
#   18   2.10754040e+03  2.10747571e+03  2.44e-09 1.53e-16  6.74e-07     1s
#   19   2.10750165e+03  2.10749760e+03  5.62e-10 1.67e-16  4.21e-08     1s
#   20   2.10749876e+03  2.10749873e+03  1.74e-09 1.73e-16  3.56e-10     1s
#   21   2.10749874e+03  2.10749874e+03  5.00e-12 1.24e-12  4.58e-14     2s
#
# Barrier solved model in 21 iterations and 1.55 seconds (0.72 work units)
# Optimal objective 2.10749874e+03
#
# Crossover log...
#
#     5838 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 8.8144769e-14      2s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5841    2.1074987e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 5841 iterations and 1.73 seconds (0.82 work units)
# Optimal objective  2.107498738e+03
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 96367 primals, 210247 duals
# Objective: 2.11e+03
# Solver model: available
# Solver message: 2
#
# C:\Users\Marvin\AppData\Local\Temp\ipykernel_37456\1490851207.py:16: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# 0.58
# INFO:linopy.model: Solve linear problem using Gurobi solver
# Writing constraints.: 100%|██████████| 16/16 [00:01<00:00, 15.45it/s]
# Writing continuous variables.: 100%|██████████| 7/7 [00:00<00:00, 36.17it/s]
# Read LP format model from file C:\Users\Marvin\AppData\Local\Temp\linopy-problem-vqjvky98.lp
# Reading time = 0.31 seconds
# obj: 210247 rows, 96367 columns, 385446 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 210247 rows, 96367 columns and 385446 nonzeros
# Model fingerprint: 0x3d80c80f
# Coefficient statistics:
#   Matrix range     [9e-01, 4e+00]
#   Objective range  [8e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-05, 1e+01]
# Presolve removed 157688 rows and 39469 columns
# Presolve time: 0.15s
# Presolved: 52559 rows, 56898 columns, 153253 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  Dense cols : 3
#  AA' NZ     : 1.139e+05
#  Factor NZ  : 6.570e+05 (roughly 50 MB of memory)
#  Factor Ops : 8.838e+06 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.89865084e+04 -3.70972799e+05  1.36e+01 4.69e-02  4.57e+01     0s
#    1   1.83976047e+04 -2.38835844e+05  2.68e+00 3.94e-01  7.11e+00     0s
#    2   1.50670468e+04 -2.49421940e+04  5.64e-02 2.21e-02  6.07e-01     0s
#    3   6.82220607e+03 -1.65863031e+03  1.04e-03 1.69e-03  9.84e-02     0s
#    4   4.00720580e+03  2.26405609e+02  2.62e-04 5.28e-04  4.13e-02     1s
#    5   3.27037081e+03  8.23590895e+02  1.62e-04 2.49e-04  2.64e-02     1s
#    6   2.83206201e+03  1.08166289e+03  1.14e-04 1.77e-04  1.88e-02     1s
#    7   2.54709739e+03  1.30876692e+03  8.24e-05 1.15e-04  1.32e-02     1s
#    8   2.12950546e+03  1.56813437e+03  3.13e-05 3.92e-05  5.98e-03     1s
#    9   1.97925889e+03  1.69274286e+03  1.55e-05 1.66e-05  3.04e-03     1s
#   10   1.91519399e+03  1.77511248e+03  9.02e-06 6.11e-06  1.48e-03     1s
#   11   1.86710323e+03  1.79769069e+03  4.28e-06 2.25e-06  7.32e-04     1s
#   12   1.84802099e+03  1.81100070e+03  2.34e-06 5.88e-07  3.89e-04     1s
#   13   1.83699776e+03  1.81609056e+03  1.26e-06 1.91e-07  2.20e-04     1s
#   14   1.82740005e+03  1.82134027e+03  3.42e-07 3.33e-16  6.36e-05     1s
#   15   1.82527059e+03  1.82248091e+03  1.55e-07 1.67e-16  2.93e-05     1s
#   16   1.82394140e+03  1.82326224e+03  3.83e-08 1.26e-16  7.09e-06     1s
#   17   1.82354377e+03  1.82336622e+03  7.03e-09 1.34e-16  1.86e-06     1s
#   18   1.82344748e+03  1.82343118e+03  4.96e-10 1.65e-16  1.71e-07     1s
#   19   1.82344138e+03  1.82344098e+03  2.93e-10 4.28e-12  4.20e-09     1s
#   20   1.82344114e+03  1.82344114e+03  8.94e-10 1.49e-13  1.67e-11     2s
#
# Barrier solved model in 20 iterations and 1.54 seconds (0.70 work units)
# Optimal objective 1.82344114e+03
#
# Crossover log...
#
#     6242 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 7.2511441e-14      2s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6245    1.8234411e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 6245 iterations and 1.72 seconds (0.80 work units)
# Optimal objective  1.823441138e+03
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 96367 primals, 210247 duals
# Objective: 1.82e+03
# Solver model: available
# Solver message: 2
#
# C:\Users\Marvin\AppData\Local\Temp\ipykernel_37456\1490851207.py:16: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# 0.48
# INFO:linopy.model: Solve linear problem using Gurobi solver
# Writing constraints.: 100%|██████████| 16/16 [00:01<00:00, 15.52it/s]
# Writing continuous variables.: 100%|██████████| 7/7 [00:00<00:00, 35.69it/s]
# Read LP format model from file C:\Users\Marvin\AppData\Local\Temp\linopy-problem-nlbkqhuj.lp
# Reading time = 0.31 seconds
# obj: 210247 rows, 96367 columns, 385446 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 210247 rows, 96367 columns and 385446 nonzeros
# Model fingerprint: 0xabfe3bf6
# Coefficient statistics:
#   Matrix range     [9e-01, 4e+00]
#   Objective range  [8e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-05, 1e+01]
# Presolve removed 157688 rows and 39469 columns
# Presolve time: 0.15s
# Presolved: 52559 rows, 56898 columns, 153253 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  Dense cols : 3
#  AA' NZ     : 1.139e+05
#  Factor NZ  : 6.570e+05 (roughly 50 MB of memory)
#  Factor Ops : 8.838e+06 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.26853509e+04 -3.32068297e+05  1.35e+01 3.89e-02  4.09e+01     0s
#    1   1.56913130e+04 -2.13887639e+05  2.68e+00 3.53e-01  6.35e+00     0s
#    2   1.29484301e+04 -2.29977421e+04  5.62e-02 2.00e-02  5.47e-01     0s
#    3   5.67477846e+03 -1.47427104e+03  9.89e-04 1.39e-03  8.25e-02     0s
#    4   3.47307977e+03  1.55798946e+02  2.70e-04 4.70e-04  3.60e-02     1s
#    5   3.30164368e+03  5.47690025e+02  2.30e-04 2.97e-04  2.96e-02     1s
#    6   2.52239738e+03  9.52256790e+02  1.26e-04 1.16e-04  1.67e-02     1s
#    7   2.14928209e+03  1.12172245e+03  8.02e-05 6.85e-05  1.09e-02     1s
#    8   1.85997194e+03  1.35627365e+03  4.35e-05 1.70e-05  5.29e-03     1s
#    9   1.68031044e+03  1.43271469e+03  2.00e-05 1.67e-06  2.60e-03     1s
#   10   1.60363644e+03  1.47848709e+03  1.05e-05 9.25e-07  1.31e-03     1s
#   11   1.57943119e+03  1.49122788e+03  7.52e-06 6.11e-07  9.23e-04     1s
#   12   1.56255075e+03  1.49764334e+03  5.37e-06 7.37e-08  6.79e-04     1s
#   13   1.55312039e+03  1.50029025e+03  4.23e-06 6.37e-08  5.53e-04     1s
#   14   1.54731692e+03  1.50284825e+03  3.54e-06 5.39e-08  4.65e-04     1s
#   15   1.54109094e+03  1.50466386e+03  2.77e-06 4.66e-08  3.81e-04     1s
#   16   1.53951767e+03  1.50772221e+03  2.60e-06 3.48e-08  3.33e-04     1s
#   17   1.52817184e+03  1.51161380e+03  1.22e-06 2.88e-09  1.73e-04     1s
#   18   1.52230064e+03  1.51527130e+03  5.06e-07 1.67e-16  7.36e-05     1s
#   19   1.52011177e+03  1.51596926e+03  2.42e-07 1.11e-16  4.34e-05     1s
#   20   1.51901014e+03  1.51677387e+03  1.16e-07 1.11e-16  2.35e-05     2s
#   21   1.51858837e+03  1.51703788e+03  6.83e-08 8.33e-17  1.63e-05     2s
#   22   1.51816451e+03  1.51757340e+03  2.39e-08 8.33e-17  6.21e-06     2s
#   23   1.51800679e+03  1.51766079e+03  8.67e-09 6.67e-17  3.64e-06     2s
#   24   1.51795388e+03  1.51770686e+03  3.63e-09 6.75e-17  2.61e-06     2s
#   25   1.51791305e+03  1.51787353e+03  2.66e-10 8.33e-17  4.17e-07     2s
#   26   1.51791012e+03  1.51790750e+03  1.41e-10 8.71e-17  2.75e-08     2s
#   27   1.51790972e+03  1.51790962e+03  4.28e-10 8.33e-17  1.08e-09     2s
#   28   1.51790968e+03  1.51790968e+03  2.93e-11 3.62e-12  1.88e-14     2s
#
# Barrier solved model in 28 iterations and 2.06 seconds (0.85 work units)
# Optimal objective 1.51790968e+03
#
# Crossover log...
#
#     6904 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.0063478e-13      2s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6907    1.5179097e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 6907 iterations and 2.27 seconds (0.96 work units)
# Optimal objective  1.517909684e+03
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 96367 primals, 210247 duals
# Objective: 1.52e+03
# Solver model: available
# Solver message: 2
#
# C:\Users\Marvin\AppData\Local\Temp\ipykernel_37456\1490851207.py:16: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# 0.38
# INFO:linopy.model: Solve linear problem using Gurobi solver
# Writing constraints.: 100%|██████████| 16/16 [00:01<00:00, 15.50it/s]
# Writing continuous variables.: 100%|██████████| 7/7 [00:00<00:00, 35.96it/s]
# Read LP format model from file C:\Users\Marvin\AppData\Local\Temp\linopy-problem-43sz2vqk.lp
# Reading time = 0.31 seconds
# obj: 210247 rows, 96367 columns, 385446 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 210247 rows, 96367 columns and 385446 nonzeros
# Model fingerprint: 0xcd62b17e
# Coefficient statistics:
#   Matrix range     [9e-01, 4e+00]
#   Objective range  [8e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-05, 1e+01]
# Presolve removed 157688 rows and 39469 columns
# Presolve time: 0.16s
# Presolved: 52559 rows, 56898 columns, 153253 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  Dense cols : 3
#  AA' NZ     : 1.139e+05
#  Factor NZ  : 6.570e+05 (roughly 50 MB of memory)
#  Factor Ops : 8.838e+06 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.63820546e+04 -2.87788959e+05  1.35e+01 3.09e-02  3.53e+01     0s
#    1   1.29778839e+04 -1.85437429e+05  2.67e+00 3.05e-01  5.49e+00     0s
#    2   1.07970158e+04 -2.05410970e+04  5.60e-02 1.75e-02  4.77e-01     0s
#    3   4.42542384e+03 -1.30844260e+03  9.01e-04 1.20e-03  6.61e-02     0s
#    4   3.11082361e+03  1.06349514e+02  3.33e-04 2.97e-04  3.24e-02     1s
#    5   2.42630690e+03  5.81991389e+02  1.98e-04 1.04e-04  1.96e-02     1s
#    6   2.02043205e+03  7.83153254e+02  1.31e-04 4.41e-05  1.31e-02     1s
#    7   1.66520246e+03  9.35238469e+02  7.62e-05 3.32e-05  7.69e-03     1s
#    8   1.50150390e+03  1.07260573e+03  5.04e-05 8.67e-06  4.49e-03     1s
#    9   1.36999512e+03  1.12610475e+03  2.98e-05 8.88e-16  2.55e-03     1s
#   10   1.32169255e+03  1.14442055e+03  2.23e-05 6.66e-16  1.85e-03     1s
#   11   1.31967221e+03  1.14853998e+03  2.20e-05 8.88e-16  1.78e-03     1s
#   12   1.27676351e+03  1.15380235e+03  1.54e-05 8.88e-16  1.28e-03     1s
#   13   1.25438509e+03  1.15641908e+03  1.19e-05 6.66e-16  1.02e-03     1s
#   14   1.24278180e+03  1.16385245e+03  1.03e-05 4.44e-16  8.22e-04     1s
#   15   1.22605303e+03  1.16667519e+03  7.75e-06 4.44e-16  6.18e-04     1s
#   16   1.21627489e+03  1.16735809e+03  6.24e-06 2.22e-16  5.10e-04     1s
#   17   1.20581521e+03  1.17048968e+03  4.62e-06 2.22e-16  3.68e-04     1s
#   18   1.20160262e+03  1.17092937e+03  3.97e-06 2.22e-16  3.19e-04     1s
#
# Barrier performed 18 iterations in 1.37 seconds (0.65 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    21074    1.1762563e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 21074 iterations and 1.44 seconds (3.13 work units)
# Optimal objective  1.176256262e+03
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 96367 primals, 210247 duals
# Objective: 1.18e+03
# Solver model: available
# Solver message: 2
#
# C:\Users\Marvin\AppData\Local\Temp\ipykernel_37456\1490851207.py:16: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# 0.28
# INFO:linopy.model: Solve linear problem using Gurobi solver
# Writing constraints.: 100%|██████████| 16/16 [00:01<00:00, 15.65it/s]
# Writing continuous variables.: 100%|██████████| 7/7 [00:00<00:00, 36.42it/s]
# Read LP format model from file C:\Users\Marvin\AppData\Local\Temp\linopy-problem-yw47wjtf.lp
# Reading time = 0.31 seconds
# obj: 210247 rows, 96367 columns, 385446 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 210247 rows, 96367 columns and 385446 nonzeros
# Model fingerprint: 0xdd8275c4
# Coefficient statistics:
#   Matrix range     [9e-01, 4e+00]
#   Objective range  [8e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-05, 1e+01]
# Presolve removed 157688 rows and 39469 columns
# Presolve time: 0.15s
# Presolved: 52559 rows, 56898 columns, 153253 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  Dense cols : 3
#  AA' NZ     : 1.139e+05
#  Factor NZ  : 6.570e+05 (roughly 50 MB of memory)
#  Factor Ops : 8.838e+06 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.00735297e+04 -2.35046009e+05  1.35e+01 2.28e-02  2.88e+01     0s
#    1   1.02532434e+04 -1.51466647e+05  2.66e+00 2.49e-01  4.47e+00     0s
#    2   8.59870878e+03 -1.72870927e+04  5.57e-02 1.44e-02  3.93e-01     0s
#    3   3.43899533e+03 -1.07601623e+03  8.33e-04 9.16e-04  5.17e-02     0s
#    4   2.05415868e+03  1.17849798e+02  2.72e-04 1.92e-04  2.09e-02     1s
#    5   1.60868041e+03  4.25982567e+02  1.29e-04 6.67e-05  1.26e-02     1s
#    6   1.38522063e+03  5.47276365e+02  9.20e-05 6.49e-05  8.86e-03     1s
#    7   1.23948012e+03  6.31875736e+02  6.82e-05 4.84e-05  6.40e-03     1s
#    8   1.06755624e+03  7.36806240e+02  4.02e-05 1.37e-05  3.46e-03     1s
#    9   9.75230537e+02  7.73562603e+02  2.47e-05 8.88e-16  2.11e-03     1s
#   10   9.03993119e+02  7.83251232e+02  1.35e-05 6.66e-16  1.26e-03     1s
#   11   8.74308867e+02  7.95561985e+02  8.92e-06 4.44e-16  8.22e-04     1s
#   12   8.56282951e+02  7.99053242e+02  6.14e-06 3.33e-16  5.98e-04     1s
#   13   8.42475787e+02  8.02866192e+02  4.04e-06 2.22e-16  4.14e-04     1s
#   14   8.35350242e+02  8.08281098e+02  2.96e-06 2.22e-16  2.83e-04     1s
#   15   8.31376031e+02  8.09670566e+02  2.36e-06 2.22e-16  2.27e-04     1s
#   16   8.29596061e+02  8.11725948e+02  2.10e-06 1.11e-16  1.86e-04     1s
#   17   8.28755279e+02  8.12629753e+02  1.99e-06 1.11e-16  1.68e-04     1s
#
# Barrier performed 17 iterations in 1.31 seconds (0.63 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    19345    8.1511244e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 19345 iterations and 1.39 seconds (3.07 work units)
# Optimal objective  8.151124357e+02
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 96367 primals, 210247 duals
# Objective: 8.15e+02
# Solver model: available
# Solver message: 2
#
# C:\Users\Marvin\AppData\Local\Temp\ipykernel_37456\1490851207.py:16: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
#Ausgabe der Sensitivitätsanalyse des zweiten Netzwerks
results
# Out:
#       Kapital- und marginale kosten €/a  Verbrauchseinsparung €/a  \
# 1.38                       10865.200412               2697.164749
# 1.28                       10620.186645               2592.903244
# 1.18                       10374.416670               2485.974471
# 1.08                       10125.165417               2385.369071
# 0.98                        9876.495461               2278.147853
# 0.88                        9624.091037               2170.189135
# 0.78                        9371.093000               2054.684523
# 0.68                        9114.338231               1935.714688
# 0.58                        8855.387434               1806.042075
# 0.48                        8599.717710               1618.280978
# 0.38                        8305.896408               1485.947886
# 0.28                        7970.540406               1473.192444
#
#       Marginale Kosten €/a  Ursprüngliche Energiekosten €/a  \
# 1.38           3442.425264                      6139.590013
# 1.28           3216.286619                      5809.189863
# 1.18           2992.815241                      5478.789712
# 1.08           2763.020491                      5148.389562
# 0.98           2539.841559                      4817.989412
# 0.88           2317.400127                      4487.589262
# 0.78           2102.504589                      4157.189112
# 0.68           1891.074274                      3826.788961
# 0.58           1690.346736                      3496.388811
# 0.48           1547.707683                      3165.988661
# 0.38           1349.640625                      2835.588511
# 0.28           1031.995916                      2505.188361
#
#       Investitionskosten €/a  Einspeiseverguetung €/a  Amortisationsdauer a  \
# 1.38             7422.775148               441.800030             58.007396
# 1.28             7403.900026               447.292863             60.194302
# 1.18             7381.601429               453.783753             62.604033
# 1.08             7362.144925               459.235246             65.081291
# 0.98             7336.653902               467.738569             67.920560
# 0.88             7306.690910               476.727241             71.023219
# 0.78             7268.588412               489.879659             74.644923
# 0.68             7223.263957               506.839493             78.764334
# 0.58             7165.040698               531.946295             83.774800
# 0.48             7052.010026               581.808026             92.097851
# 0.38             6956.255783               629.640146             99.010953
# 0.28             6938.544490               655.427970             99.627778
#
#       Netzbezug kWh/a  Netzeinspeisung kWh/a  PV-Ertragssumme kWh/a  \
# 1.38      2494.511061            5522.500372            11581.69408
# 1.28      2512.723921            5591.160786            11581.69408
# 1.18      2536.284103            5672.296919            11581.69408
# 1.08      2558.352307            5740.440573            11581.69408
# 0.98      2591.675061            5846.732108            11581.69408
# 0.88      2633.409235            5959.090507            11581.69408
# 0.78      2695.518703            6123.495740            11581.69408
# 0.68      2780.991579            6335.493657            11581.69408
# 0.58      2914.390924            6649.328690            11581.69408
# 0.48      3224.391007            7272.600326            11581.69408
# 0.38      3551.685855            7870.501823            11581.69408
# 0.28      3685.699701            8192.849627            11581.69408
#
#       Einspeicherung kWh/a  Auspeicherung kWh/a  Pufferspeicherkapazität l  \
# 1.38           1959.441078          1116.029571                1446.820581
# 1.28           1915.168964          1098.557644                1390.861052
# 1.18           1851.727391          1073.388590                1361.315334
# 1.08           1792.459066          1047.936970                1351.749287
# 0.98           1712.119986          1011.882149                1315.194743
# 0.88           1609.996957           964.485758                1284.435415
# 0.78           1472.907290           897.848598                1221.453476
# 0.68           1297.228770           808.417570                1137.972916
# 0.58           1048.884181           673.861695                1033.072131
# 0.48            493.733467           338.607170                 916.251465
# 0.38              0.000000             0.000000                 777.578995
# 0.28              0.000000             0.000000                 532.769859
#
#       Batteriepeicherkapazität kWh  Leistung Wärmepumpe kW
# 1.38                      5.859046                     3.0
# 1.28                      5.651274                     3.0
# 1.18                      5.368748                     3.0
# 1.08                      5.105794                     3.0
# 0.98                      4.785637                     3.0
# 0.88                      4.396937                     3.0
# 0.78                      3.926843                     3.0
# 0.68                      3.376326                     3.0
# 0.58                      2.666769                     3.0
# 0.48                      1.201256                     3.0
# 0.38                      0.000000                     3.0
# 0.28                      0.000000                     3.0
